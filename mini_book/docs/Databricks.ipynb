# %% [markdown]
# ## Introduction to the Databricks Environment

# %% [markdown]
# ### The Databricks Data Science Ecosystem
#
# Databricks offers a [Community Edition](https://community.cloud.databricks.com/login.html) of their Data Science ecosystem for running experiments and notebooks. You can sign up for a free account and start running the notebooks for the course.
#
# ### The Welcome page
#
# As you log in, this is the screen that you see.
#
# ![Welcome page](https://courseraimages.s3-us-west-2.amazonaws.com/welcome_page.png)

# %% [markdown]
# You can import a notebook into the workspace using the tab on the left. Use it to import the notebooks for the course.
#
# ![S3](https://courseraimages.s3-us-west-2.amazonaws.com/import.png)

# %% [markdown]
# ![Import notebooks](images/import2.png)

# %% [markdown]
# Upload a notebook or provide a path to a notebook. Once it has been successfully uploaded, you should see a page such as the one shown below.
#
#
# ![Imported notebooks](https://courseraimages.s3-us-west-2.amazonaws.com/import3.png)

# %% [markdown]
# ### The Cluster Page
#
# Launch a cluster to run the notebook by selecting the configuration for the image.
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/cluster_launch.png)

# %% [markdown]
# Once launched, you should see a green circle.
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/cluster_active.png)

# %% [markdown]
# You can click on the Clusters tab on the left and check the status of the available clusters.
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/cluster_list.png)

# %% [markdown]
# If any libraries were installed during the creation of the cluster, they would show up here.
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/cluster_library.png)

# %% [markdown]
# Install a Python library by providing the library name and a version. It is a good idea to specify the version explicitly.
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/cluster_library2.png)

# %% [markdown]
# ### The Notebook Interface
#
# Attach a running cluster to the notebook
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/notebook_cluster.png)

# %% [markdown]
# The File dropdown menu
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/notebook_file.png)

# %% [markdown]
# The Edit dropdown menu
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/notebook_edit.png)

# %% [markdown]
# Execute the code cell.
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/code_run.png)

# %% [markdown]
# ### Git Integration
#
# Integrate with a Git repository
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/Git.png)

# %% [markdown]
# Version control the notebook and save to the remote Git repository.
#
# ![Cluster launch page](https://courseraimages.s3-us-west-2.amazonaws.com/version.png)
